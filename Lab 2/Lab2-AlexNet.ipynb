# %%
import os
import numpy as np
from random import shuffle
from skimage.io import imread
from skimage.transform import resize
from tensorflow.keras.layers import Input, Dense, Flatten, Conv2D, MaxPooling2D, Activation, Dropout
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import SGD, Adam, RMSprop

# %%
def gen_labels(im_name, pat1, pat2):
    '''
    Parameters
    ----------
    im_name : Str
    The image file name.
    pat1 : Str
    A string pattern in the filename for 1st class, e.g "Mel"
    pat2 : Str
    A string pattern in the filename 2nd class, e.g, "Nev"
    Returns
    -------
    Label : Numpy array
    Class label of the filename name based on its pattern.
    '''
    if pat1 in im_name:
        label = np.array([0])
    elif pat2 in im_name:
        label = np.array([1])
    return label

def get_data(data_path, data_list, img_h, img_w):
    """

    Parameters
    ----------
    train_data_path : Str
    Path to the data directory
    train_list : List
    A list containing the name of the images.
    img_h : Int
    image height to be resized to.
    img_w : Int
    image width to be resized to.
    Returns
    -------
    img_labels : Nested List
    A nested list containing the loaded images along with their
    correcponding labels.
    """
    img_labels = []

    for item in enumerate(data_list):
        img = imread(os.path.join(data_path, item[1]), as_gray = True) # "as_grey"
        img = resize(img, (img_h, img_w), anti_aliasing = True).astype('float32')
        img_labels.append([np.array(img), gen_labels(item[1], 'Mel', 'Nev')])

        if item[0] % 100 == 0:
            print('Reading: {0}/{1} of train images'.format(item[0], len(data_list)))

    shuffle(img_labels)

    return img_labels

def get_data_arrays(nested_list, img_h, img_w):
    """
    Parameters
    ----------
    nested_list : nested list
    nested list of image arrays with corresponding class labels.
    img_h : Int
    Image height.
    img_w : Int
    Image width.
    Returns
    -------
    img_arrays : Numpy array
    4D Array with the size of (n_data,img_h,img_w, 1)
    label_arrays : Numpy array
    1D array with the size (n_data).
    """
    img_arrays = np.zeros((len(nested_list), img_h, img_w), dtype = np.float32)
    label_arrays = np.zeros((len(nested_list)), dtype = np.int32)
    for ind in range(len(nested_list)):
        img_arrays[ind] = nested_list[ind][0]
        label_arrays[ind] = nested_list[ind][1]
    img_arrays = np.expand_dims(img_arrays, axis =3)
    return img_arrays, label_arrays

def get_train_test_arrays(train_data_path, test_data_path, train_list,
test_list, img_h, img_w):
    """
    Get the directory to the train and test sets, the files names and
    the size of the image and return the image and label arrays for
    train and test sets.
    """
    train_data = get_data(train_data_path, train_list, img_h, img_w)
    test_data = get_data(test_data_path, test_list, img_h, img_w)
    
    train_img, train_label = get_data_arrays(train_data, img_h, img_w)
    test_img, test_label = get_data_arrays(test_data, img_h, img_w)
    del(train_data)
    del(test_data)
    return train_img, test_img, train_label, test_label

# %%
img_w, img_h = 128, 128 # Setting the width and heights of the images.
#data_path = 'Data//DL_course//Lab1//Skin//' # Path to data root with two subdirs.
data_path = 'Data/DL_course/Lab1/Skin/' # Path to data root with two subdirs.
train_data_path = os.path.join(data_path, 'train')
test_data_path = os.path.join(data_path, 'test')

train_list = os.listdir(train_data_path)
test_list = os.listdir(test_data_path)

x_train, x_test, y_train, y_test = get_train_test_arrays(
    train_data_path, test_data_path,
    train_list, test_list, img_h, img_w)

#When using hinge instead of BinaryCrossEntropy as loss function 
#y_test[y_test == 0] = -1
#y_train[y_train == 0] = -1
# Out:
# Reading: 0/1000 of train images
# Reading: 100/1000 of train images
# Reading: 200/1000 of train images
# Reading: 300/1000 of train images
# Reading: 400/1000 of train images
# Reading: 500/1000 of train images
# Reading: 600/1000 of train images
# Reading: 700/1000 of train images
# Reading: 800/1000 of train images
# Reading: 900/1000 of train images
# Reading: 0/200 of train images
# Reading: 100/200 of train images

# %%
def model(img_width, img_height, img_ch, base):
   
    model1 = Sequential()
    
    model1.add(Conv2D(filters=base, input_shape=(img_width, img_height, img_ch), kernel_size=(3,3),
    strides=(1,1), padding='same'))
    model1.add(Activation('relu'))
    model1.add(MaxPooling2D(pool_size=(2,2)))
   
    model1.add(Conv2D(filters= base *2, kernel_size=(3,3), strides=(1,1), padding='same'))
    model1.add(Activation('relu'))
    model1.add(MaxPooling2D(pool_size=(2,2)))
    
    model1.add(Conv2D(filters= base *4, kernel_size=(3,3), strides=(1,1), padding='same'))
    model1.add(Activation('relu'))
    
    model1.add(Conv2D(filters= base *4, kernel_size=(3,3), strides=(1,1), padding='same'))
    model1.add(Activation('relu'))
    
    model1.add(Conv2D(filters= base *2, kernel_size=(3,3), strides=(1,1), padding='same'))
    model1.add(Activation('relu'))
    model1.add(MaxPooling2D(pool_size=(2,2)))
    
    model1.add(Flatten())
    model1.add(Dense(128))
    #model1.add(Dropout(0.4))
    model1.add(Activation('relu'))
    
    model1.add(Dense(64))
    #model1.add(Dropout(0.4))
    model1.add(Activation('relu'))
    
    model1.add(Dense(1))
    #model1.add(Dropout(0.4))
    model1.add(Activation('sigmoid'))
    
    model1.summary()
    
    return model1

# %%
img_ch = x_train[0].shape[2]
base=8

clf = model(img_w, img_h, img_ch, base)

clf.compile(loss='BinaryCrossentropy', optimizer = Adam(learning_rate = 0.00001), metrics=['binary_accuracy']) 
#clf.compile(loss='hinge', optimizer = Adam(learning_rate = 0.00001), metrics=['binary_accuracy']) 

clf_hist = clf.fit(x_train, y_train, shuffle=True, epochs = 150, batch_size = 2, verbose=1, validation_data=[x_test, y_test])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 8)       80
#
#  activation (Activation)     (None, 128, 128, 8)       0
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 8)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 16)        1168
#
#  activation_1 (Activation)   (None, 64, 64, 16)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 16)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 32)        4640
#
#  activation_2 (Activation)   (None, 32, 32, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 32)        9248
#
#  activation_3 (Activation)   (None, 32, 32, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 16)        4624
#
#  activation_4 (Activation)   (None, 32, 32, 16)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 128)               524416
#
#  activation_5 (Activation)   (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  activation_6 (Activation)   (None, 64)                0
#
#  dense_2 (Dense)             (None, 1)                 65
#
#  activation_7 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 552,497
# Trainable params: 552,497
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 500/500 [==============================] - 6s 8ms/step - loss: 0.6927 - binary_accuracy: 0.5250 - val_loss: 0.6917 - val_binary_accuracy: 0.5000
# Epoch 2/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.6917 - binary_accuracy: 0.5510 - val_loss: 0.6906 - val_binary_accuracy: 0.5000
# Epoch 3/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.6899 - binary_accuracy: 0.6020 - val_loss: 0.6890 - val_binary_accuracy: 0.5000
# Epoch 4/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.6879 - binary_accuracy: 0.5570 - val_loss: 0.6854 - val_binary_accuracy: 0.6400
# Epoch 5/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.6828 - binary_accuracy: 0.5960 - val_loss: 0.6785 - val_binary_accuracy: 0.7700
# Epoch 6/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.6758 - binary_accuracy: 0.6510 - val_loss: 0.6802 - val_binary_accuracy: 0.5000
# Epoch 7/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.6684 - binary_accuracy: 0.6230 - val_loss: 0.6596 - val_binary_accuracy: 0.7600
# Epoch 8/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.6549 - binary_accuracy: 0.6830 - val_loss: 0.6541 - val_binary_accuracy: 0.5350
# Epoch 9/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.6392 - binary_accuracy: 0.6850 - val_loss: 0.6339 - val_binary_accuracy: 0.6700
# Epoch 10/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.6291 - binary_accuracy: 0.6990 - val_loss: 0.6192 - val_binary_accuracy: 0.7500
# Epoch 11/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.6180 - binary_accuracy: 0.6970 - val_loss: 0.6106 - val_binary_accuracy: 0.7300
# Epoch 12/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.5985 - binary_accuracy: 0.7100 - val_loss: 0.5919 - val_binary_accuracy: 0.7600
# Epoch 13/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.5891 - binary_accuracy: 0.7410 - val_loss: 0.5797 - val_binary_accuracy: 0.7750
# Epoch 14/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.5819 - binary_accuracy: 0.7140 - val_loss: 0.5699 - val_binary_accuracy: 0.7850
# Epoch 15/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.5685 - binary_accuracy: 0.7370 - val_loss: 0.5592 - val_binary_accuracy: 0.7800
# Epoch 16/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.5592 - binary_accuracy: 0.7380 - val_loss: 0.5488 - val_binary_accuracy: 0.7700
# Epoch 17/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.5513 - binary_accuracy: 0.7340 - val_loss: 0.5429 - val_binary_accuracy: 0.7800
# Epoch 18/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.5449 - binary_accuracy: 0.7210 - val_loss: 0.5710 - val_binary_accuracy: 0.7400
# Epoch 19/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.5376 - binary_accuracy: 0.7460 - val_loss: 0.5312 - val_binary_accuracy: 0.7750
# Epoch 20/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.5366 - binary_accuracy: 0.7400 - val_loss: 0.5304 - val_binary_accuracy: 0.7750
# Epoch 21/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.5322 - binary_accuracy: 0.7460 - val_loss: 0.5235 - val_binary_accuracy: 0.7800
# Epoch 22/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.5258 - binary_accuracy: 0.7420 - val_loss: 0.5185 - val_binary_accuracy: 0.7950
# Epoch 23/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.5207 - binary_accuracy: 0.7500 - val_loss: 0.5266 - val_binary_accuracy: 0.7850
# Epoch 24/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.5230 - binary_accuracy: 0.7580 - val_loss: 0.5107 - val_binary_accuracy: 0.8100
# Epoch 25/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.5177 - binary_accuracy: 0.7540 - val_loss: 0.5074 - val_binary_accuracy: 0.8000
# Epoch 26/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.5161 - binary_accuracy: 0.7570 - val_loss: 0.5046 - val_binary_accuracy: 0.7950
# Epoch 27/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.5146 - binary_accuracy: 0.7480 - val_loss: 0.5254 - val_binary_accuracy: 0.7450
# Epoch 28/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.5127 - binary_accuracy: 0.7580 - val_loss: 0.5060 - val_binary_accuracy: 0.8050
# Epoch 29/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.5117 - binary_accuracy: 0.7490 - val_loss: 0.5302 - val_binary_accuracy: 0.7800
# Epoch 30/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.5110 - binary_accuracy: 0.7560 - val_loss: 0.5237 - val_binary_accuracy: 0.7500
# Epoch 31/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.5070 - binary_accuracy: 0.7590 - val_loss: 0.4973 - val_binary_accuracy: 0.8200
# Epoch 32/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.5013 - binary_accuracy: 0.7650 - val_loss: 0.5007 - val_binary_accuracy: 0.7800
# Epoch 33/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.5036 - binary_accuracy: 0.7630 - val_loss: 0.5101 - val_binary_accuracy: 0.7900
# Epoch 34/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.5024 - binary_accuracy: 0.7680 - val_loss: 0.5282 - val_binary_accuracy: 0.7400
# Epoch 35/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4958 - binary_accuracy: 0.7640 - val_loss: 0.5000 - val_binary_accuracy: 0.8000
# Epoch 36/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4997 - binary_accuracy: 0.7650 - val_loss: 0.5061 - val_binary_accuracy: 0.7650
# Epoch 37/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4969 - binary_accuracy: 0.7720 - val_loss: 0.4895 - val_binary_accuracy: 0.8100
# Epoch 38/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.5002 - binary_accuracy: 0.7680 - val_loss: 0.4958 - val_binary_accuracy: 0.8100
# Epoch 39/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4942 - binary_accuracy: 0.7790 - val_loss: 0.4916 - val_binary_accuracy: 0.8150
# Epoch 40/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4956 - binary_accuracy: 0.7760 - val_loss: 0.4881 - val_binary_accuracy: 0.8150
# Epoch 41/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4883 - binary_accuracy: 0.7800 - val_loss: 0.4837 - val_binary_accuracy: 0.8150
# Epoch 42/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4920 - binary_accuracy: 0.7600 - val_loss: 0.4846 - val_binary_accuracy: 0.8150
# Epoch 43/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4897 - binary_accuracy: 0.7650 - val_loss: 0.4954 - val_binary_accuracy: 0.8000
# Epoch 44/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4860 - binary_accuracy: 0.7670 - val_loss: 0.4962 - val_binary_accuracy: 0.8050
# Epoch 45/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4883 - binary_accuracy: 0.7670 - val_loss: 0.5185 - val_binary_accuracy: 0.7650
# Epoch 46/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4867 - binary_accuracy: 0.7790 - val_loss: 0.4969 - val_binary_accuracy: 0.7800
# Epoch 47/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4876 - binary_accuracy: 0.7690 - val_loss: 0.4834 - val_binary_accuracy: 0.8050
# Epoch 48/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4834 - binary_accuracy: 0.7730 - val_loss: 0.4777 - val_binary_accuracy: 0.8100
# Epoch 49/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4792 - binary_accuracy: 0.7900 - val_loss: 0.4824 - val_binary_accuracy: 0.8100
# Epoch 50/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4795 - binary_accuracy: 0.7820 - val_loss: 0.4911 - val_binary_accuracy: 0.7950
# Epoch 51/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4780 - binary_accuracy: 0.7890 - val_loss: 0.4800 - val_binary_accuracy: 0.8100
# Epoch 52/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4778 - binary_accuracy: 0.7850 - val_loss: 0.5027 - val_binary_accuracy: 0.8000
# Epoch 53/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4753 - binary_accuracy: 0.7780 - val_loss: 0.4836 - val_binary_accuracy: 0.8000
# Epoch 54/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4706 - binary_accuracy: 0.7750 - val_loss: 0.4789 - val_binary_accuracy: 0.8100
# Epoch 55/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4725 - binary_accuracy: 0.7830 - val_loss: 0.4719 - val_binary_accuracy: 0.8150
# Epoch 56/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4726 - binary_accuracy: 0.7850 - val_loss: 0.4723 - val_binary_accuracy: 0.8200
# Epoch 57/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4770 - binary_accuracy: 0.7810 - val_loss: 0.4761 - val_binary_accuracy: 0.8150
# Epoch 58/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4739 - binary_accuracy: 0.7840 - val_loss: 0.4772 - val_binary_accuracy: 0.8050
# Epoch 59/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4743 - binary_accuracy: 0.7770 - val_loss: 0.4784 - val_binary_accuracy: 0.8050
# Epoch 60/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4670 - binary_accuracy: 0.7880 - val_loss: 0.4817 - val_binary_accuracy: 0.8050
# Epoch 61/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4668 - binary_accuracy: 0.7850 - val_loss: 0.4824 - val_binary_accuracy: 0.8100
# Epoch 62/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4666 - binary_accuracy: 0.7890 - val_loss: 0.4709 - val_binary_accuracy: 0.8100
# Epoch 63/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4652 - binary_accuracy: 0.7910 - val_loss: 0.5078 - val_binary_accuracy: 0.7900
# Epoch 64/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4676 - binary_accuracy: 0.7960 - val_loss: 0.4731 - val_binary_accuracy: 0.8100
# Epoch 65/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4652 - binary_accuracy: 0.7900 - val_loss: 0.5189 - val_binary_accuracy: 0.7750
# Epoch 66/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4621 - binary_accuracy: 0.7870 - val_loss: 0.4770 - val_binary_accuracy: 0.8050
# Epoch 67/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4601 - binary_accuracy: 0.7930 - val_loss: 0.4698 - val_binary_accuracy: 0.8100
# Epoch 68/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4650 - binary_accuracy: 0.7770 - val_loss: 0.4636 - val_binary_accuracy: 0.8250
# Epoch 69/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4593 - binary_accuracy: 0.7860 - val_loss: 0.4808 - val_binary_accuracy: 0.8050
# Epoch 70/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4596 - binary_accuracy: 0.7860 - val_loss: 0.4635 - val_binary_accuracy: 0.8200
# Epoch 71/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4571 - binary_accuracy: 0.7980 - val_loss: 0.4883 - val_binary_accuracy: 0.7950
# Epoch 72/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4588 - binary_accuracy: 0.7940 - val_loss: 0.4649 - val_binary_accuracy: 0.8300
# Epoch 73/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4537 - binary_accuracy: 0.7950 - val_loss: 0.4703 - val_binary_accuracy: 0.8200
# Epoch 74/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4622 - binary_accuracy: 0.7940 - val_loss: 0.4904 - val_binary_accuracy: 0.7850
# Epoch 75/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4536 - binary_accuracy: 0.8080 - val_loss: 0.4753 - val_binary_accuracy: 0.8200
# Epoch 76/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4529 - binary_accuracy: 0.8050 - val_loss: 0.4978 - val_binary_accuracy: 0.7600
# Epoch 77/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4525 - binary_accuracy: 0.7880 - val_loss: 0.4653 - val_binary_accuracy: 0.8100
# Epoch 78/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4483 - binary_accuracy: 0.7990 - val_loss: 0.4600 - val_binary_accuracy: 0.8300
# Epoch 79/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4514 - binary_accuracy: 0.8020 - val_loss: 0.4630 - val_binary_accuracy: 0.8100
# Epoch 80/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4524 - binary_accuracy: 0.7960 - val_loss: 0.4874 - val_binary_accuracy: 0.7950
# Epoch 81/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4490 - binary_accuracy: 0.7850 - val_loss: 0.4622 - val_binary_accuracy: 0.8250
# Epoch 82/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4477 - binary_accuracy: 0.8040 - val_loss: 0.4631 - val_binary_accuracy: 0.8100
# Epoch 83/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4428 - binary_accuracy: 0.8130 - val_loss: 0.4775 - val_binary_accuracy: 0.7950
# Epoch 84/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4463 - binary_accuracy: 0.8020 - val_loss: 0.4615 - val_binary_accuracy: 0.8150
# Epoch 85/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4417 - binary_accuracy: 0.8130 - val_loss: 0.4608 - val_binary_accuracy: 0.8250
# Epoch 86/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4442 - binary_accuracy: 0.8030 - val_loss: 0.4614 - val_binary_accuracy: 0.8300
# Epoch 87/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4420 - binary_accuracy: 0.8060 - val_loss: 0.4666 - val_binary_accuracy: 0.8150
# Epoch 88/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4377 - binary_accuracy: 0.8070 - val_loss: 0.4698 - val_binary_accuracy: 0.8100
# Epoch 89/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4398 - binary_accuracy: 0.8060 - val_loss: 0.4624 - val_binary_accuracy: 0.8250
# Epoch 90/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4427 - binary_accuracy: 0.7920 - val_loss: 0.4630 - val_binary_accuracy: 0.8100
# Epoch 91/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4358 - binary_accuracy: 0.8140 - val_loss: 0.4731 - val_binary_accuracy: 0.8050
# Epoch 92/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4407 - binary_accuracy: 0.8150 - val_loss: 0.4853 - val_binary_accuracy: 0.8050
# Epoch 93/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4360 - binary_accuracy: 0.8200 - val_loss: 0.5908 - val_binary_accuracy: 0.7000
# Epoch 94/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4380 - binary_accuracy: 0.8000 - val_loss: 0.4688 - val_binary_accuracy: 0.8050
# Epoch 95/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4337 - binary_accuracy: 0.8150 - val_loss: 0.4663 - val_binary_accuracy: 0.8100
# Epoch 96/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4308 - binary_accuracy: 0.8140 - val_loss: 0.4593 - val_binary_accuracy: 0.8200
# Epoch 97/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4351 - binary_accuracy: 0.8060 - val_loss: 0.4639 - val_binary_accuracy: 0.8200
# Epoch 98/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4337 - binary_accuracy: 0.8090 - val_loss: 0.4706 - val_binary_accuracy: 0.8250
# Epoch 99/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4250 - binary_accuracy: 0.8160 - val_loss: 0.4588 - val_binary_accuracy: 0.8100
# Epoch 100/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4277 - binary_accuracy: 0.8120 - val_loss: 0.4580 - val_binary_accuracy: 0.8100
# Epoch 101/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4271 - binary_accuracy: 0.8170 - val_loss: 0.4625 - val_binary_accuracy: 0.8200
# Epoch 102/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4265 - binary_accuracy: 0.8150 - val_loss: 0.4735 - val_binary_accuracy: 0.8250
# Epoch 103/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4248 - binary_accuracy: 0.8120 - val_loss: 0.4746 - val_binary_accuracy: 0.8200
# Epoch 104/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4246 - binary_accuracy: 0.8110 - val_loss: 0.4577 - val_binary_accuracy: 0.8100
# Epoch 105/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4272 - binary_accuracy: 0.8110 - val_loss: 0.4591 - val_binary_accuracy: 0.8200
# Epoch 106/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4196 - binary_accuracy: 0.8140 - val_loss: 0.4726 - val_binary_accuracy: 0.8100
# Epoch 107/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4223 - binary_accuracy: 0.8190 - val_loss: 0.4577 - val_binary_accuracy: 0.8200
# Epoch 108/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4188 - binary_accuracy: 0.8150 - val_loss: 0.4722 - val_binary_accuracy: 0.8250
# Epoch 109/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4196 - binary_accuracy: 0.8200 - val_loss: 0.4616 - val_binary_accuracy: 0.8150
# Epoch 110/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4165 - binary_accuracy: 0.8300 - val_loss: 0.4671 - val_binary_accuracy: 0.8250
# Epoch 111/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4208 - binary_accuracy: 0.8150 - val_loss: 0.4557 - val_binary_accuracy: 0.8150
# Epoch 112/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4188 - binary_accuracy: 0.8150 - val_loss: 0.4602 - val_binary_accuracy: 0.8100
# Epoch 113/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4147 - binary_accuracy: 0.8130 - val_loss: 0.4658 - val_binary_accuracy: 0.8250
# Epoch 114/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4125 - binary_accuracy: 0.8220 - val_loss: 0.4799 - val_binary_accuracy: 0.8150
# Epoch 115/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4097 - binary_accuracy: 0.8160 - val_loss: 0.4560 - val_binary_accuracy: 0.8250
# Epoch 116/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4123 - binary_accuracy: 0.8110 - val_loss: 0.4588 - val_binary_accuracy: 0.8200
# Epoch 117/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4066 - binary_accuracy: 0.8170 - val_loss: 0.4788 - val_binary_accuracy: 0.7850
# Epoch 118/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4060 - binary_accuracy: 0.8260 - val_loss: 0.4675 - val_binary_accuracy: 0.8050
# Epoch 119/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4035 - binary_accuracy: 0.8210 - val_loss: 0.4588 - val_binary_accuracy: 0.8150
# Epoch 120/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4058 - binary_accuracy: 0.8160 - val_loss: 0.4573 - val_binary_accuracy: 0.8150
# Epoch 121/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4050 - binary_accuracy: 0.8230 - val_loss: 0.4628 - val_binary_accuracy: 0.8200
# Epoch 122/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4087 - binary_accuracy: 0.8190 - val_loss: 0.4602 - val_binary_accuracy: 0.8100
# Epoch 123/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4049 - binary_accuracy: 0.8130 - val_loss: 0.4612 - val_binary_accuracy: 0.8200
# Epoch 124/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.3994 - binary_accuracy: 0.8270 - val_loss: 0.4897 - val_binary_accuracy: 0.8000
# Epoch 125/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4013 - binary_accuracy: 0.8370 - val_loss: 0.4644 - val_binary_accuracy: 0.8350
# Epoch 126/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4042 - binary_accuracy: 0.8200 - val_loss: 0.4663 - val_binary_accuracy: 0.8100
# Epoch 127/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.3981 - binary_accuracy: 0.8240 - val_loss: 0.4603 - val_binary_accuracy: 0.8150
# Epoch 128/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.3949 - binary_accuracy: 0.8220 - val_loss: 0.5011 - val_binary_accuracy: 0.7850
# Epoch 129/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.4002 - binary_accuracy: 0.8230 - val_loss: 0.4628 - val_binary_accuracy: 0.8100
# Epoch 130/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.3935 - binary_accuracy: 0.8350 - val_loss: 0.4651 - val_binary_accuracy: 0.8250
# Epoch 131/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.3917 - binary_accuracy: 0.8170 - val_loss: 0.4627 - val_binary_accuracy: 0.8100
# Epoch 132/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.3949 - binary_accuracy: 0.8220 - val_loss: 0.5022 - val_binary_accuracy: 0.7750
# Epoch 133/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.3922 - binary_accuracy: 0.8210 - val_loss: 0.4644 - val_binary_accuracy: 0.8150
# Epoch 134/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.3925 - binary_accuracy: 0.8390 - val_loss: 0.4612 - val_binary_accuracy: 0.8200
# Epoch 135/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.3891 - binary_accuracy: 0.8370 - val_loss: 0.4667 - val_binary_accuracy: 0.8150
# Epoch 136/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.3873 - binary_accuracy: 0.8240 - val_loss: 0.4626 - val_binary_accuracy: 0.8150
# Epoch 137/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.3851 - binary_accuracy: 0.8290 - val_loss: 0.4677 - val_binary_accuracy: 0.8000
# Epoch 138/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.3834 - binary_accuracy: 0.8320 - val_loss: 0.4852 - val_binary_accuracy: 0.7900
# Epoch 139/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.3808 - binary_accuracy: 0.8350 - val_loss: 0.4674 - val_binary_accuracy: 0.8350
# Epoch 140/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.3778 - binary_accuracy: 0.8360 - val_loss: 0.4761 - val_binary_accuracy: 0.7950
# Epoch 141/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.3887 - binary_accuracy: 0.8310 - val_loss: 0.4693 - val_binary_accuracy: 0.8350
# Epoch 142/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.3805 - binary_accuracy: 0.8450 - val_loss: 0.5006 - val_binary_accuracy: 0.7800
# Epoch 143/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.3771 - binary_accuracy: 0.8370 - val_loss: 0.4616 - val_binary_accuracy: 0.8150
# Epoch 144/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.3755 - binary_accuracy: 0.8350 - val_loss: 0.4727 - val_binary_accuracy: 0.8300
# Epoch 145/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.3766 - binary_accuracy: 0.8360 - val_loss: 0.4733 - val_binary_accuracy: 0.8200
# Epoch 146/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.3710 - binary_accuracy: 0.8330 - val_loss: 0.4681 - val_binary_accuracy: 0.8100
# Epoch 147/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.3732 - binary_accuracy: 0.8340 - val_loss: 0.4759 - val_binary_accuracy: 0.8300
# Epoch 148/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.3702 - binary_accuracy: 0.8490 - val_loss: 0.4735 - val_binary_accuracy: 0.8050
# Epoch 149/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.3699 - binary_accuracy: 0.8300 - val_loss: 0.4737 - val_binary_accuracy: 0.8200
# Epoch 150/150
# 500/500 [==============================] - 4s 7ms/step - loss: 0.3651 - binary_accuracy: 0.8370 - val_loss: 0.4613 - val_binary_accuracy: 0.8250

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(4, 4))
plt.title("Learning curve")
plt.plot(clf_hist.history["loss"], label="loss")
plt.plot(clf_hist.history["val_loss"], label="val_loss")
plt.plot( np.argmin(clf_hist.history["val_loss"]),
            np.min(clf_hist.history["val_loss"]),
            marker="x", color="r", label="best model")

plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend();
plt.show()

plt.figure(figsize=(4, 4))
plt.title("Learning curve")
plt.plot(clf_hist.history["binary_accuracy"], label="accuracy")
plt.plot(clf_hist.history["val_binary_accuracy"], label="val_accuracy")
plt.plot( np.argmax(clf_hist.history["val_binary_accuracy"]),
            np.max(clf_hist.history["val_binary_accuracy"]),
            marker="x", color="r", label="best model")

plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend();
