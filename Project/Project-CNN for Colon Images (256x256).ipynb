# %% [markdown]
# # Project - Colon Tumor Classification (256x256)

# %% [markdown]
# Lab Group 8:
#
# - Gnana Spandana Akumalla
# - Patrik Svensson
# - Serkan Arda Yilal

# %% [markdown]
# In this file, we are doing hyperparameter tuning on selected number of colon images with tumor and non-tumor labels. We use an image size of 256x256 and train VGG16 models from scratch and evaluate their performances in different metrics.

# %%
import os 
import time
import gc
import pickle
from datetime import datetime
from timeit import default_timer as timer
import random
random.seed(0)

from keras.layers import Dense, Conv2D,MaxPooling2D, Flatten, Dropout
import tensorflow as tf 
tf.random.set_seed(0)
import keras
from statistics import mean as mean_calc

from tensorflow.keras.layers import Input, Dense, Flatten, Conv2D, MaxPooling2D, Activation, Dropout, BatchNormalization, SpatialDropout2D
from tensorflow.keras.layers import ZeroPadding2D, Convolution2D, MaxPooling2D, Conv2D, Conv2DTranspose, concatenate


from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.metrics import Precision, Recall, AUC, Accuracy

import pandas as pd
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(0)

from Utils_project import load_data, hyperparameter_tuner, pretrained_hyperparameter_tuner, distribution_check, train_val_folds

from Models import vgg16_model, MLP_model

import psutil

# %% [markdown]
# Checking GPU availability

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
from tensorflow.python.client import device_lib

device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 16866647838304947054
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 10908663808
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 7494666523685488113
#  physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:0a:00.0, compute capability: 6.1"
#  xla_global_id: 416903419]

# %% [markdown]
# We first, set the paths for saving trained models, training histories, and training result reports.

# %%
current_dir =os.getcwd()


best_models_path = os.path.join(current_dir, "best_models")
model_histories_path = os.path.join(current_dir, "model_histories")
training_results_path = os.path.join(current_dir, "training_results")

paths = [best_models_path, model_histories_path, training_results_path]

if not os.path.exists(best_models_path):
    os.mkdir(best_models_path)
    print("best models directory is created " + best_models_path)
    
if not os.path.exists(model_histories_path):
    os.mkdir(model_histories_path)
    print("model histories directory is created " + model_histories_path)
    
if not os.path.exists(training_results_path):
    os.mkdir(training_results_path)
    print("training results directory is created " + training_results_path)

# %% [markdown]
# Defining data directory for tumor and non-tumor images along with their sizes

# %%
# Defining paths
data_dir = 'project_dataset/colon_images/'
NT_dir = os.path.join(data_dir, 'non-tumor/') # nT=non-Tumor
T_dir = os.path.join(data_dir, 'tumor/') # T=Tumor

# Defining constants
img_height=256
img_width=256

# %%
print("Total number of non-tumor images:",len(os.listdir(NT_dir)))
print("Total number of tumor images:",len(os.listdir(T_dir)))
# Out:
# Total number of non-tumor images: 6494
# Total number of tumor images: 3515

# %% [markdown]
# ## Data loading and pre-processing

# %% [markdown]
# Loading images. Due to memory problems, we had to choose 2000 images per class in greyscale.

# %%
# Loads images 
t0=time.time()

NT_imgs = load_data(NT_dir, img_height, img_width, number_of_images = 2000, color = False)

print("Loading", len(NT_imgs)," non-tumor images took", round(time.time()-t0), "seconds")

t1=time.time()

T_imgs = load_data(T_dir, img_height, img_width, number_of_images = 2000, color = False)

print("Loading", len(T_imgs)," tumor images took", round(time.time()-t1), "seconds")
# Out:
# Loading 2000  non-tumor images took 83 seconds
# Loading 2000  tumor images took 78 seconds

# %%
# For inspection
for inspect_img in range(0,4,2):
    f, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, sharey=True)
    ax1.imshow(T_imgs[inspect_img])
    ax2.imshow(T_imgs[inspect_img+1])
    ax3.imshow(NT_imgs[inspect_img])
    ax4.imshow(NT_imgs[inspect_img+1])
    ax1.set_title("Tumor")
    ax2.set_title("Tumor")
    ax3.set_title("Non-Tumor")
    ax4.set_title("Non-Tumor")

    plt.show()

# %% [markdown]
# Now we convert images into arrays.

# %% [markdown]
# Converting image lists to numpy arrays and preparing label vectors for each class.

# %%
T_X=np.array(T_imgs)
NT_X=np.array(NT_imgs)
T_y = np.ones([len(T_imgs),1])
NT_y = np.zeros([len(NT_imgs),1])

del T_imgs, NT_imgs

gc.collect()
# Out:
# 9196

# %%
print("Tumor data size",T_X.shape)
print("Tumor label size", T_y.shape)
print("Non-tumor data size",NT_X.shape)
print("Non-tumor label size", NT_y.shape)
# Out:
# Tumor data size (2000, 256, 256)
# Tumor label size (2000, 1)
# Non-tumor data size (2000, 256, 256)
# Non-tumor label size (2000, 1)

# %% [markdown]
# Combining images from tumor and non-tumor class.

# %%
X = np.concatenate((T_X, NT_X))
y = np.concatenate((T_y, NT_y))

del T_X, NT_X, T_y, NT_y
gc.collect()
# Out:
# 0

# %%
X, y = shuffle(X, y, random_state=0)

# %%
X.shape
# Out:
# (4000, 256, 256)

# %% [markdown]
# Distribution of labels in training folds are checked.

# %%
k = 3
distribution_check(k,y)
# Out:
# fold 1 has 1333 zeros and 1333 ones
# fold 2 has 1333 zeros and 1333 ones
# fold 3 has 1334 zeros and 1334 ones

# %% [markdown]
# We see that distribution of classes in folds are balanced.

# %% [markdown]
# We will divide images into 3 folds to use in 3-fold cross-validation.

# %%
X_train_folds, X_val_folds, y_train_folds, y_val_folds = train_val_folds(X, y, k)
del X, y
gc.collect()
# Out:
# Loop 1: Training data size: 2667, Validation data size: 1333
# Loop 2: Training data size: 2667, Validation data size: 1333
# Loop 3: Training data size: 2666, Validation data size: 1334
# 0

# %% [markdown]
# We set the setting values to be evaluated in hyperparameter tuning

# %%
ch = 1
n_base_list = [8, 16, 32]
dropout_list = [0.2]
dense_layers_list = [[32,32],[64, 64],[128,128]]
n_class = 2
l2_reg_list = [0.0001]
loss = "BinaryCrossentropy"
lr_list = [0.0001]
batch_size = 32
epochs = 125
metrics = [AUC(), "binary_accuracy", Precision(), Recall()] 
act_func_list = ["relu","tanh"]

tuning_report = hyperparameter_tuner(X_train_folds, y_train_folds,X_val_folds, y_val_folds, paths, k, img_width, img_height, ch, n_base_list, dropout_list, dense_layers_list, 
                        n_class, l2_reg_list, loss, lr_list, act_func_list, metrics, epochs, batch_size, verbose= 0, summary = False)
# Out:
# Start time for hyperparameter tuning operation = 06-11-2023_18-06-42
# best models directory for this training session is created /home/group_8/best_models/best_models_session_06-11-2023_18-06-42
# model histories directory for this training session is created /home/group_8/model_histories/model_histories_session_06-11-2023_18-06-42
# 1 settings have been checked and saved to report file
# svmem(total=67340759040, available=41432039424, percent=38.5, used=25106014208, free=8650903552, active=13128409088, inactive=33574096896, buffers=6743117824, cached=26840723456, shared=53051392, slab=11233452032)
# svmem(total=67340759040, available=40965869568, percent=39.2, used=25572188160, free=10497142784, active=13130260480, inactive=31733739520, buffers=6743715840, cached=24527712256, shared=53051392, slab=11233075200)
# svmem(total=67340759040, available=41129377792, percent=38.9, used=25408675840, free=10909351936, active=13133475840, inactive=31327682560, buffers=6744293376, cached=24278437888, shared=53055488, slab=11233026048)
# svmem(total=67340759040, available=42086912000, percent=37.5, used=24451141632, free=12560846848, active=13134036992, inactive=29672108032, buffers=6744702976, cached=23584067584, shared=53055488, slab=11233214464)
# svmem(total=67340759040, available=42042310656, percent=37.6, used=24495742976, free=12484640768, active=13134815232, inactive=29724213248, buffers=6745210880, cached=23615164416, shared=53055488, slab=11232956416)
# 6 settings have been checked and saved to report file
# svmem(total=67340759040, available=41611190272, percent=38.2, used=24926859264, free=12023603200, active=13135523840, inactive=30208016384, buffers=6745796608, cached=23644499968, shared=53055488, slab=11232768000)
# svmem(total=67340759040, available=41543024640, percent=38.3, used=24995028992, free=11907678208, active=13137248256, inactive=30330310656, buffers=6746636288, cached=23691415552, shared=53055488, slab=11232686080)
# svmem(total=67340759040, available=41663135744, percent=38.1, used=24874921984, free=11980668928, active=13144469504, inactive=30245941248, buffers=6747430912, cached=23737737216, shared=53051392, slab=11233124352)
# svmem(total=67340759040, available=41241042944, percent=38.8, used=25297014784, free=11503206400, active=13145448448, inactive=30708125696, buffers=6748131328, cached=23792406528, shared=53051392, slab=11232702464)
# svmem(total=67340759040, available=40713846784, percent=39.5, used=25824210944, free=11034210304, active=13146353664, inactive=31156617216, buffers=6748983296, cached=23733354496, shared=53051392, slab=11234017280)
# 11 settings have been checked and saved to report file
# svmem(total=67340759040, available=41849090048, percent=37.9, used=24688967680, free=12337041408, active=13148717056, inactive=29859581952, buffers=6749696000, cached=23565053952, shared=53051392, slab=11234533376)
# svmem(total=67340759040, available=41604628480, percent=38.2, used=24933429248, free=12020072448, active=13152706560, inactive=30177910784, buffers=6751670272, cached=23635587072, shared=53051392, slab=11234254848)
# svmem(total=67340759040, available=38193319936, percent=43.3, used=28344717312, free=8616624128, active=13154627584, inactive=33573670912, buffers=6753374208, cached=23626043392, shared=53051392, slab=11233689600)
# svmem(total=67340759040, available=41488166912, percent=38.4, used=25049882624, free=11754659840, active=13156683776, inactive=30438658048, buffers=6755037184, cached=23781179392, shared=53051392, slab=11234078720)
# svmem(total=67340759040, available=37900242944, percent=43.7, used=28637814784, free=8386281472, active=13163151360, inactive=33790996480, buffers=6758072320, cached=23558590464, shared=53051392, slab=11234021376)

# %% [markdown]
# Due to a memory issue training hyperparameter tuning, we had to rerun the remaining settings that were not run. Later on, their results were combined with the previous hyperparameter tuning operation's results.

# %%
ch = 1
n_base_list = [32]
dropout_list = [0.2]
dense_layers_list = [[64, 64]]
n_class = 2
l2_reg_list = [0.0001]
loss = "BinaryCrossentropy"
lr_list = [0.0001]
batch_size = 32
epochs = 125
metrics = [AUC(), "binary_accuracy", Precision(), Recall()] 
act_func_list = ["tanh"]

# %%
tuning_report = hyperparameter_tuner(X_train_folds, y_train_folds,X_val_folds, y_val_folds, paths, k, img_width, img_height, ch, n_base_list, dropout_list, dense_layers_list, 
                        n_class, l2_reg_list, loss, lr_list, act_func_list, metrics, epochs, batch_size, verbose= 0, summary = False)
# Out:
# Start time for hyperparameter tuning operation = 07-11-2023_20-03-43
# best models directory for this training session is created /home/group_8/best_models/best_models_session_07-11-2023_20-03-43
# model histories directory for this training session is created /home/group_8/model_histories/model_histories_session_07-11-2023_20-03-43
# 1 settings have been checked and saved to report file
# svmem(total=67340759040, available=32422273024, percent=51.9, used=34099007488, free=5205479424, active=15365201920, inactive=36532334592, buffers=6397939712, cached=21638332416, shared=69828608, slab=9262624768)
# Training end date is: 2023-11-07 21:19:54.445575
# Total Training Time is: 01-01-1970_01-16-11

# %%
ch = 1
n_base_list = [32]
dropout_list = [0.2]
dense_layers_list = [[128, 128]]
n_class = 2
l2_reg_list = [0.0001]
loss = "BinaryCrossentropy"
lr_list = [0.0001]
batch_size = 32
epochs = 125
metrics = [AUC(), "binary_accuracy", Precision(), Recall()] 
act_func_list = ["relu","tanh"]

# %%
tuning_report = hyperparameter_tuner(X_train_folds, y_train_folds,X_val_folds, y_val_folds, paths, k, img_width, img_height, ch, n_base_list, dropout_list, dense_layers_list, 
                        n_class, l2_reg_list, loss, lr_list, act_func_list, metrics, epochs, batch_size, verbose= 0, summary = False)
# Out:
# Start time for hyperparameter tuning operation = 07-11-2023_21-26-58
# best models directory for this training session is created /home/group_8/best_models/best_models_session_07-11-2023_21-26-58
# model histories directory for this training session is created /home/group_8/model_histories/model_histories_session_07-11-2023_21-26-58
# 1 settings have been checked and saved to report file
# svmem(total=67340759040, available=34479423488, percent=48.8, used=32041832448, free=6966988800, active=15937183744, inactive=34227941376, buffers=6396522496, cached=21935415296, shared=69853184, slab=9261391872)
# svmem(total=67340759040, available=33085366272, percent=50.9, used=33435897856, free=7770042368, active=13743788032, inactive=35610619904, buffers=6398328832, cached=19736489984, shared=69844992, slab=9261342720)
# Training end date is: 2023-11-07 23:59:19.774504
# Total Training Time is: 01-01-1970_02-32-20
